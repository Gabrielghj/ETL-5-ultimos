# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrielghj/ETL-5-ultimos/blob/main/ETL_5_%C3%BAltimos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ETL SKILL

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
skill= pd.read_csv('skill_migration_public.csv')
skill.drop_duplicates(inplace=True)

# %%
columns_to_check = skill.columns[12:]

columns_to_drop = []

for column in columns_to_check:
    if skill[column].isnull().all():
        columns_to_drop.append(column)

skill.drop(columns=columns_to_drop, inplace=True)

# %%
column_rename_map = {}
for column in skill.columns:
    if column.startswith("net_per_10K_"):
        new_column_name = column.replace("net_per_10K_", "")
        column_rename_map[column] = new_column_name

skill.rename(columns=column_rename_map, inplace=True)

# %%
columns_to_drop = ["wb_income", "wb_region", "skill_group_id"]
skill.drop(columns=columns_to_drop, inplace=True)

# %%
skill_arg = skill[skill["country_name"] == "Argentina"]
skill_arg.reset_index(drop=True, inplace=True)

# %%
skill_Italy = skill[skill["country_name"] == "Italy"]
skill_Italy.reset_index(drop=True, inplace=True)

# %%
skill_spain = skill[skill["country_name"] == "Spain"]
skill_spain.reset_index(drop=True, inplace=True)

# %%
skill_usa = skill[skill["country_name"] == "United States"]
skill_usa.reset_index(drop=True, inplace=True)

# %%
skill_arg
# Out:
#     country_code country_name         skill_group_category  \
# 0             ar    Argentina  Specialized Industry Skills
# 1             ar    Argentina              Business Skills
# 2             ar    Argentina              Business Skills
# 3             ar    Argentina  Specialized Industry Skills
# 4             ar    Argentina              Business Skills
# ..           ...          ...                          ...
# 166           ar    Argentina  Specialized Industry Skills
# 167           ar    Argentina  Specialized Industry Skills
# 168           ar    Argentina  Specialized Industry Skills
# 169           ar    Argentina  Specialized Industry Skills
# 170           ar    Argentina  Specialized Industry Skills
#
#                skill_group_name    2015    2016    2017    2018    2019
# 0                     Sociology  -38.90 -126.02  -62.94  -71.28 -327.67
# 1           Affiliate Marketing -134.97  -28.22   30.55  -83.54 -323.41
# ...

# %%
skill_Italy
# Out:
#     country_code country_name         skill_group_category  \
# 0             it        Italy  Specialized Industry Skills
# 1             it        Italy                  Soft Skills
# 2             it        Italy                  Tech Skills
# 3             it        Italy                  Soft Skills
# 4             it        Italy       Disruptive Tech Skills
# ..           ...          ...                          ...
# 226           it        Italy  Specialized Industry Skills
# 227           it        Italy  Specialized Industry Skills
# 228           it        Italy  Specialized Industry Skills
# 229           it        Italy  Specialized Industry Skills
# 230           it        Italy  Specialized Industry Skills
#
#                  skill_group_name    2015    2016    2017    2018    2019
# 0               National Security  -88.28 -386.81 -244.31  -49.02 -250.94
# 1                      Persuasion -193.98 -301.18  148.29 -127.24 -200.93
# ...

# %%
skill_spain
# Out:
#     country_code country_name         skill_group_category  \
# 0             es        Spain  Specialized Industry Skills
# 1             es        Spain       Disruptive Tech Skills
# 2             es        Spain  Specialized Industry Skills
# 3             es        Spain  Specialized Industry Skills
# 4             es        Spain  Specialized Industry Skills
# ..           ...          ...                          ...
# 230           es        Spain                  Soft Skills
# 231           es        Spain  Specialized Industry Skills
# 232           es        Spain              Business Skills
# 233           es        Spain  Specialized Industry Skills
# 234           es        Spain              Business Skills
#
#            skill_group_name    2015    2016    2017    2018    2019
# 0                 Pathology -165.72  -71.54   37.72   69.23   -3.11
# 1     Aerospace Engineering  -98.29  -13.11   30.08   -3.43   -2.33
# ...

# %%
skill_usa
# Out:
#     country_code   country_name         skill_group_category  \
# 0             us  United States  Specialized Industry Skills
# 1             us  United States                  Tech Skills
# 2             us  United States  Specialized Industry Skills
# 3             us  United States  Specialized Industry Skills
# 4             us  United States  Specialized Industry Skills
# ..           ...            ...                          ...
# 244           us  United States                  Tech Skills
# 245           us  United States       Disruptive Tech Skills
# 246           us  United States                  Tech Skills
# 247           us  United States       Disruptive Tech Skills
# 248           us  United States       Disruptive Tech Skills
#
#                    skill_group_name    2015    2016    2017    2018    2019
# 0             Reading Comprehension  -11.44    6.17    0.38   -2.17   -6.28
# 1                      Social Media   -0.58  -20.32   -6.17  -12.47   -5.77
# ...

# %% [markdown]
# ETL salarios trabajadores total

# %%
salarios= pd.read_csv('salarios_trabajadores_total.csv')

# %%
columns_to_drop = salarios.columns[2:35]
salarios.drop(columns=columns_to_drop, inplace=True)

# %%
columnas_anios = salarios.columns[3:]
salarios.dropna(subset=columnas_anios, how='all', inplace=True)

# %%
salarios.dropna(axis=1, how='all', inplace=True)

# %%
salarios
# Out:
#                     Country Name Country Code       1991       1992  \
# 1    Africa Eastern and Southern          AFE  24.941109  24.716870
# 2                    Afghanistan          AFG   7.206729   7.254014
# 3     Africa Western and Central          AFW  14.191762  14.184831
# 4                         Angola          AGO  37.095650  36.993790
# 5                        Albania          ALB  35.601370  34.910350
# ..                           ...          ...        ...        ...
# 260                        Samoa          WSM  62.165510  61.974560
# 262                  Yemen, Rep.          YEM  48.717060  48.911790
# 263                 South Africa          ZAF  82.281240  82.171280
# 264                       Zambia          ZMB  19.118200  18.939700
# 265                     Zimbabwe          ZWE  36.337260  35.887540
#
#           1993       1994       1995       1996       1997       1998  ...  \
# ...

# %% [markdown]
# ETL salarios trabajadores mujeres

# %%
salarios_M= pd.read_csv('salarios_trabajadores_mujeres.csv')

# %%
columns_to_drop = salarios_M.columns[2:35]
salarios_M.drop(columns=columns_to_drop, inplace=True)

# %%
columnas_anios = salarios_M.columns[3:]
salarios_M.dropna(subset=columnas_anios, how='all', inplace=True)

# %%
salarios_M.dropna(axis=1, how='all', inplace=True)

# %%
salarios_M
# Out:
#                     Country Name Country Code       1991       1992  \
# 1    Africa Eastern and Southern          AFE  17.261888  17.252284
# 2                    Afghanistan          AFG   0.951877   1.003353
# 3     Africa Western and Central          AFW   8.767142   8.792289
# 4                         Angola          AGO  22.366920  22.544370
# 5                        Albania          ALB  37.136600  36.740500
# ..                           ...          ...        ...        ...
# 260                        Samoa          WSM  59.990870  59.766590
# 262                  Yemen, Rep.          YEM  29.864790  30.195140
# 263                 South Africa          ZAF  77.497060  77.433940
# 264                       Zambia          ZMB   8.680133   8.758533
# 265                     Zimbabwe          ZWE  17.905710  18.100550
#
#           1993       1994       1995       1996       1997       1998  ...  \
# ...

# %% [markdown]
# ETL salarios trabajadores hombres

# %%
salarios_H= pd.read_csv('salarios_trabajadores_hombres.csv')

# %%
columns_to_drop = salarios_H.columns[2:35]
salarios_H.drop(columns=columns_to_drop, inplace=True)

# %%
columnas_anios = salarios_M.columns[3:]
salarios_H.dropna(subset=columnas_anios, how='all', inplace=True)

# %%
salarios_H.dropna(axis=1, how='all', inplace=True)

# %%
salarios_H
# Out:
#                     Country Name Country Code       1991       1992  \
# 1    Africa Eastern and Southern          AFE  31.367210  30.993970
# 2                    Afghanistan          AFG   8.341757   8.381743
# 3     Africa Western and Central          AFW  18.747403  18.701560
# 4                         Angola          AGO  51.067270  50.739330
# 5                        Albania          ALB  34.502540  33.458410
# ..                           ...          ...        ...        ...
# 260                        Samoa          WSM  63.346210  63.177640
# 262                  Yemen, Rep.          YEM  53.468310  53.581680
# 263                 South Africa          ZAF  84.897990  84.793670
# 264                       Zambia          ZMB  27.623680  27.478200
# 265                     Zimbabwe          ZWE  53.122620  52.220910
#
#           1993       1994       1995       1996       1997       1998  ...  \
# ...

# %% [markdown]
# ETL tasa pobreza

# %%
pobreza= pd.read_csv('tasa_pobreza.csv')

# %%
pobreza_arg = pobreza[pobreza["Country Name"] == "Argentina"]
pobreza_arg.reset_index(drop=True, inplace=True)

# %%
pobreza_arg.drop(columns=["Indicator Code"], inplace=True)
# Out:
# <ipython-input-227-0678532ed241>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pobreza_arg.drop(columns=["Indicator Code"], inplace=True)

# %%
pobreza_arg.dropna(subset=pobreza_arg.columns[4:], how='all', inplace=True)
# Out:
# <ipython-input-228-512e6dec1b78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pobreza_arg.dropna(subset=pobreza_arg.columns[4:], how='all', inplace=True)

# %%
pobreza_arg.dropna(axis=1, how='all', inplace=True)
# Out:
# <ipython-input-229-8142c180c8c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pobreza_arg.dropna(axis=1, how='all', inplace=True)

# %%
pobreza_arg
# Out:
#    Country Name Country Code  \
# 0     Argentina          ARG
# 1     Argentina          ARG
# 2     Argentina          ARG
# 3     Argentina          ARG
# 4     Argentina          ARG
# 5     Argentina          ARG
# 6     Argentina          ARG
# 15    Argentina          ARG
# 16    Argentina          ARG
# 17    Argentina          ARG
# 18    Argentina          ARG
# 19    Argentina          ARG
# 20    Argentina          ARG
# 21    Argentina          ARG
# 22    Argentina          ARG
# 23    Argentina          ARG
# 24    Argentina          ARG
# 25    Argentina          ARG
# 26    Argentina          ARG
# 27    Argentina          ARG
# 28    Argentina          ARG
#
#                                        Indicator Name  1980  1986  1987  1991  \
# 0   Annualized average growth rate in per capita r...   NaN   NaN   NaN   NaN
# 1   Survey mean consumption or income per capita, ...   NaN   NaN   NaN   NaN
# ...
